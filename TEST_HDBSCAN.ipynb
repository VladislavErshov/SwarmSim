# %%
import hdbscan
from sklearn.datasets import make_blobs
import pandas as pd
import matplotlib.pyplot as plt

# %%
blobs, labels = make_blobs(n_samples=2000, n_features=2)

pd.DataFrame(blobs).head()
# Out:
#           0         1
# 0  4.437172  1.023984
# 1  5.615334  1.926187
# 2 -5.825525 -8.030052
# 3  6.969013  0.855039
# 4 -7.633861 -9.269511

# %%
plt.scatter(blobs[:, 0], blobs[:, 1])

# %%
clusterer = hdbscan.HDBSCAN()

# %%
clusterer.fit(blobs)
# Out:
# HDBSCAN()

# %%
cl_labels = clusterer.labels_
n_clusters = max(cl_labels)

plt.scatter(blobs[:, 0], blobs[:, 1], c=cl_labels)

# %%
import numpy as np
a = {1: 1000, 2: 10101, 3: 132132, 4: 656565}
b = np.array([0, 1, 0, 1])

# %%
print(np.where(b == 0))
# Out:
# (array([0, 2], dtype=int64),)
